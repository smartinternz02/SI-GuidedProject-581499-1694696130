# %% [markdown]
# # **ASSIGNMENT-5**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Load Dataset**

# %%
dt = pd.read_csv('/content/Mall_Customers.csv')

# %%
dt
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %% [markdown]
# # **Data Preprocessing**

# %%
dt.isnull().any()
# Out:
# CustomerID                False
# Gender                    False
# Age                       False
# Annual Income (k$)        False
# Spending Score (1-100)    False
# dtype: bool

# %%
dt.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
dt.Gender.unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
dt.Gender.value_counts()
# Out:
# Female    112
# Male       88
# Name: Gender, dtype: int64

# %%
dt=data.drop([ 'CustomerID'] , axis =1 )

# %%
dt
# Out:
#      Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0      Male   19                  15                      39
# 1      Male   21                  15                      81
# 2    Female   20                  16                       6
# 3    Female   23                  16                      77
# 4    Female   31                  17                      40
# ..      ...  ...                 ...                     ...
# 195  Female   35                 120                      79
# 196  Female   45                 126                      28
# 197    Male   32                 126                      74
# 198    Male   32                 137                      18
# 199    Male   30                 137                      83
#
# [200 rows x 4 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
dt['Gender']= le.fit_transform(dt['Gender'])

# %%
dt.head()
# Out:
#    Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0       1   19                  15                      39
# 1       1   21                  15                      81
# 2       0   20                  16                       6
# 3       0   23                  16                      77
# 4       0   31                  17                      40

# %%
dt.describe()
# Out:
#            Gender         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean     0.440000   38.850000           60.560000               50.200000
# std      0.497633   13.969007           26.264721               25.823522
# min      0.000000   18.000000           15.000000                1.000000
# 25%      0.000000   28.750000           41.500000               34.750000
# 50%      0.000000   36.000000           61.500000               50.000000
# 75%      1.000000   49.000000           78.000000               73.000000
# max      1.000000   70.000000          137.000000               99.000000

# %%
dt.corr()
# Out:
#                           Gender       Age  Annual Income (k$)  \
# Gender                  1.000000  0.060867            0.056410
# Age                     0.060867  1.000000           -0.012398
# Annual Income (k$)      0.056410 -0.012398            1.000000
# Spending Score (1-100) -0.058109 -0.327227            0.009903
#
#                         Spending Score (1-100)
# Gender                               -0.058109
# Age                                  -0.327227
# Annual Income (k$)                    0.009903
# Spending Score (1-100)                1.000000

# %%
plt.figure(figsize=(10,8))
sns.heatmap(dt.corr(),annot =True)
# Out:
# <Axes: >

# %%
dt.corr()['Spending Score (1-100)'].sort_values(ascending= False)
# Out:
# Spending Score (1-100)    1.000000
# Annual Income (k$)        0.009903
# Gender                   -0.058109
# Age                      -0.327227
# Name: Spending Score (1-100), dtype: float64

# %%
plt.pie(dt.Gender.value_counts(),[0,0.1],labels = ['Female','Male'],autopct ='%1.1f%%',shadow = True,colors = ['purple','yellow'],)
plt.title('GENDER')
plt.show()

# %%
sns.displot(dt['Spending Score (1-100)'])

# %%
sns.displot(dt['Annual Income (k$)'])

# %%
sns.displot(dt['Age'])

# %%
sns.barplot(x =dt['Gender'].value_counts().index,y =data['Gender'].value_counts() )
# Out:
# <Axes: ylabel='Gender'>

# %%
sns.pairplot(dt)

# %%
sns.lineplot( x = dt['Gender' ] , y = dt['Spending Score (1-100)'])
# Out:
# <Axes: xlabel='Gender', ylabel='Spending Score (1-100)'>

# %%
sns.lineplot( x = dt['Gender' ] , y = dt['Annual Income (k$)'])
# Out:
# <Axes: xlabel='Gender', ylabel='Annual Income (k$)'>

# %%
sns.lineplot( x = dt['Age' ] , y = dt['Spending Score (1-100)'])
# Out:
# <Axes: xlabel='Age', ylabel='Spending Score (1-100)'>

# %%
sns.lineplot(x=dt['Age'] , y =  dt['Annual Income (k$)'])
# Out:
# <Axes: xlabel='Age', ylabel='Annual Income (k$)'>

# %% [markdown]
# # CLUSTER ALGORITHM

# %%
from sklearn import cluster

error = []
for i in range(2,15):
  kmeans = cluster.KMeans(n_clusters = i)
  kmeans.fit(dt)
  error.append(kmeans.inertia_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
plt.figure(figsize=(8, 6))
plt.plot(range(2,15), error, marker='o', linestyle='-')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.title('Elbow Method')
plt.grid(True)
plt.show()

# %%
elbow_point = None
wcss=error
k_values = range(2,15)
for i in range(1, len(wcss)):
    if wcss[i - 1] - wcss[i] < 0.1 * wcss[0]:  # You can adjust the threshold as needed
        elbow_point = k_values[i - 1]
        break

print(f"The estimated elbow point is at {elbow_point} clusters.")
# Out:
# The estimated elbow point is at 5 clusters.

# %%
optimal_clusters = 5

kmeans = cluster.KMeans(n_clusters=optimal_clusters)
kmeans.fit(dt)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=5)

# %%
cluster_labels = kmeans.labels_
dt['Cluster_Labels'] = cluster_labels

# %%
dt
# Out:
#      Gender  Age  Annual Income (k$)  Spending Score (1-100)  Cluster_Labels
# 0         1   19                  15                      39               0
# 1         1   21                  15                      81               4
# 2         0   20                  16                       6               0
# 3         0   23                  16                      77               4
# 4         0   31                  17                      40               0
# ..      ...  ...                 ...                     ...             ...
# 195       0   35                 120                      79               1
# 196       0   45                 126                      28               2
# 197       1   32                 126                      74               1
# 198       1   32                 137                      18               2
# 199       1   30                 137                      83               1
#
# [200 rows x 5 columns]

# %%
dt['Cluster_Labels'].value_counts()
# Out:
# 3    79
# 1    39
# 2    36
# 0    23
# 4    23
# Name: Cluster_Labels, dtype: int64

# %%
for i in range(5):
  df = dt[dt['Cluster_Labels']== i]
  print(df)
  print(" ")
  print(" ")
# Out:
#     Gender  Age  Annual Income (k$)  Spending Score (1-100)  Cluster_Labels
# 0        1   19                  15                      39               0
# 2        0   20                  16                       6               0
# 4        0   31                  17                      40               0
# 6        0   35                  18                       6               0
# 8        1   64                  19                       3               0
# 10       1   67                  19                      14               0
# 12       0   58                  20                      15               0
# 14       1   37                  20                      13               0
# 16       0   35                  21                      35               0
# 18       1   52                  23                      29               0
# 20       1   35                  24                      35               0
# ...
